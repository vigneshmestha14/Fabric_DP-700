# %% [markdown]
# ## Introduction
# The script automates the process of downloading AdventureWorks data from GitHub, processing it, and saving it in both Parquet and CSV formats. The processed data is stored in both the lakehouse files directory and in Delta tables for further analysis and use.

# %%
import pandas as pd
from tqdm.auto import tqdm
import os

base = "https://raw.githubusercontent.com/vigneshmestha14/Fabric_DP-700/main/AdventureWorks"
lakehouse_dir = "/lakehouse/default/Files/AdventureWorks"
csv_dir = os.path.join(lakehouse_dir, "csvfiles")
parquet_dir = os.path.join(lakehouse_dir, "parquetfiles")

# Create the subdirectories if they don't exist
os.makedirs(csv_dir, exist_ok=True)
os.makedirs(parquet_dir, exist_ok=True)

# Load list of tables
df_tables = pd.read_csv(f"{base}/adventureworks.csv", names=["table"])
print("Loaded list of tables:")

for table in (pbar := tqdm(df_tables['table'].values)):
    pbar.set_description(f"Uploading {table} to lakehouse")

    # Download
    df = pd.read_parquet(f"{base}/{table}.parquet")
    print(f"Downloaded {table}.parquet")

    # Save as lakehouse table
    spark.createDataFrame(df).write.mode('overwrite').saveAsTable(table)
    print(f"Saved {table} to lakehouse table")

    # Save as local Parquet file
    parquet_output_path = os.path.join(parquet_dir, f"{table}.parquet")
    df.to_parquet(parquet_output_path)
    print(f"Saved {table} to {parquet_output_path}")

    # Save as local CSV file
    csv_output_path = os.path.join(csv_dir, f"{table}.csv")
    df.to_csv(csv_output_path, index=False)
    print(f"Saved {table} to {csv_output_path}")
# Out:
# StatementMeta(, 6770bff8-b6e0-494d-a4ee-01010fb65493, 15, Submitted, Running, Running)
# StatementMeta(, 6770bff8-b6e0-494d-a4ee-01010fb65493, 14, Finished, Available, Finished)
# Loaded list of tables:
#   0%|          | 0/28 [00:00<?, ?it/s]
# Downloaded DimDate.parquet
# Saved DimDate to lakehouse table
# Saved DimDate to /lakehouse/default/Files/AdventureWorks/parquetfiles/DimDate.parquet
# Saved DimDate to /lakehouse/default/Files/AdventureWorks/csvfiles/DimDate.csv
# Downloaded DimCustomer.parquet
# Saved DimCustomer to lakehouse table
# Saved DimCustomer to /lakehouse/default/Files/AdventureWorks/parquetfiles/DimCustomer.parquet
# Saved DimCustomer to /lakehouse/default/Files/AdventureWorks/csvfiles/DimCustomer.csv
# Downloaded DimCurrency.parquet
# Saved DimCurrency to lakehouse table
# Saved DimCurrency to /lakehouse/default/Files/AdventureWorks/parquetfiles/DimCurrency.parquet
# Saved DimCurrency to /lakehouse/default/Files/AdventureWorks/csvfiles/DimCurrency.csv
# Downloaded DimAccount.parquet
# Saved DimAccount to lakehouse table
# Saved DimAccount to /lakehouse/default/Files/AdventureWorks/parquetfiles/DimAccount.parquet
# Saved DimAccount to /lakehouse/default/Files/AdventureWorks/csvfiles/DimAccount.csv
# Downloaded DimOrganization.parquet
# Saved DimOrganization to lakehouse table
# Saved DimOrganization to /lakehouse/default/Files/AdventureWorks/parquetfiles/DimOrganization.parquet
# Saved DimOrganization to /lakehouse/default/Files/AdventureWorks/csvfiles/DimOrganization.csv
# Downloaded DimProductCategory.parquet
# Saved DimProductCategory to lakehouse table
# Saved DimProductCategory to /lakehouse/default/Files/AdventureWorks/parquetfiles/DimProductCategory.parquet
# Saved DimProductCategory to /lakehouse/default/Files/AdventureWorks/csvfiles/DimProductCategory.csv
# Downloaded DimPromotion.parquet
# Saved DimPromotion to lakehouse table
# Saved DimPromotion to /lakehouse/default/Files/AdventureWorks/parquetfiles/DimPromotion.parquet
# Saved DimPromotion to /lakehouse/default/Files/AdventureWorks/csvfiles/DimPromotion.csv
# Downloaded DimGeography.parquet
# Saved DimGeography to lakehouse table
# Saved DimGeography to /lakehouse/default/Files/AdventureWorks/parquetfiles/DimGeography.parquet
# Saved DimGeography to /lakehouse/default/Files/AdventureWorks/csvfiles/DimGeography.csv
# Downloaded DimEmployee.parquet
# Saved DimEmployee to lakehouse table
# Saved DimEmployee to /lakehouse/default/Files/AdventureWorks/parquetfiles/DimEmployee.parquet
# Saved DimEmployee to /lakehouse/default/Files/AdventureWorks/csvfiles/DimEmployee.csv
# Downloaded DimProductSubcategory.parquet
# Saved DimProductSubcategory to lakehouse table
# Saved DimProductSubcategory to /lakehouse/default/Files/AdventureWorks/parquetfiles/DimProductSubcategory.parquet
# Saved DimProductSubcategory to /lakehouse/default/Files/AdventureWorks/csvfiles/DimProductSubcategory.csv
# Downloaded DimProduct.parquet
# Saved DimProduct to lakehouse table
# Saved DimProduct to /lakehouse/default/Files/AdventureWorks/parquetfiles/DimProduct.parquet
# Saved DimProduct to /lakehouse/default/Files/AdventureWorks/csvfiles/DimProduct.csv
# Downloaded DimDepartmentGroup.parquet
# Saved DimDepartmentGroup to lakehouse table
# Saved DimDepartmentGroup to /lakehouse/default/Files/AdventureWorks/parquetfiles/DimDepartmentGroup.parquet
# Saved DimDepartmentGroup to /lakehouse/default/Files/AdventureWorks/csvfiles/DimDepartmentGroup.csv
# Downloaded FactInternetSalesReason.parquet
# Saved FactInternetSalesReason to lakehouse table
# Saved FactInternetSalesReason to /lakehouse/default/Files/AdventureWorks/parquetfiles/FactInternetSalesReason.parquet
# Saved FactInternetSalesReason to /lakehouse/default/Files/AdventureWorks/csvfiles/FactInternetSalesReason.csv
# Downloaded FactProductInventory.parquet
# Saved FactProductInventory to lakehouse table
# Saved FactProductInventory to /lakehouse/default/Files/AdventureWorks/parquetfiles/FactProductInventory.parquet
# Saved FactProductInventory to /lakehouse/default/Files/AdventureWorks/csvfiles/FactProductInventory.csv
# Downloaded DimScenario.parquet
# Saved DimScenario to lakehouse table
# Saved DimScenario to /lakehouse/default/Files/AdventureWorks/parquetfiles/DimScenario.parquet
# Saved DimScenario to /lakehouse/default/Files/AdventureWorks/csvfiles/DimScenario.csv
# Downloaded NewFactCurrencyRate.parquet
# Saved NewFactCurrencyRate to lakehouse table
# Saved NewFactCurrencyRate to /lakehouse/default/Files/AdventureWorks/parquetfiles/NewFactCurrencyRate.parquet
# Saved NewFactCurrencyRate to /lakehouse/default/Files/AdventureWorks/csvfiles/NewFactCurrencyRate.csv
# Downloaded FactSurveyResponse.parquet
# Saved FactSurveyResponse to lakehouse table
# Saved FactSurveyResponse to /lakehouse/default/Files/AdventureWorks/parquetfiles/FactSurveyResponse.parquet
# Saved FactSurveyResponse to /lakehouse/default/Files/AdventureWorks/csvfiles/FactSurveyResponse.csv
# Downloaded FactCurrencyRate.parquet
# Saved FactCurrencyRate to lakehouse table
# Saved FactCurrencyRate to /lakehouse/default/Files/AdventureWorks/parquetfiles/FactCurrencyRate.parquet
# Saved FactCurrencyRate to /lakehouse/default/Files/AdventureWorks/csvfiles/FactCurrencyRate.csv
# Downloaded FactAdditionalInternationalProductDescription.parquet
# Saved FactAdditionalInternationalProductDescription to lakehouse table
# Saved FactAdditionalInternationalProductDescription to /lakehouse/default/Files/AdventureWorks/parquetfiles/FactAdditionalInternationalProductDescription.parquet
# Saved FactAdditionalInternationalProductDescription to /lakehouse/default/Files/AdventureWorks/csvfiles/FactAdditionalInternationalProductDescription.csv
# Downloaded FactInternetSales.parquet
# Saved FactInternetSales to lakehouse table
